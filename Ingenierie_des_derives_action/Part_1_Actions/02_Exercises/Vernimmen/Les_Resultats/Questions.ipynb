# %% [markdown]
# <details>
#     <summary>
#         <b>Une entreprise lève 500M€ de capitaux propres pour réaliser un projet de recherche et développement : s'est-elle enrichie ou appauvrie ? De combien ? Même question sachant qu'elle a dépensé la moitié les deux premières années et que le projet ne donnera aucun résultat. Même question sachant que la troisième année, avec le reste de ses fonds, elle acquiert une entreprise avec une prime de 25% par rapport à sa valeur, ce qui lui permettra d'améliorer son résultat cette année-là uniquement de 75M€ grâce à des synergies. </b>
#     </summary>
#
# > L'entreprise ne s'est ni enrichie, ni appauvrie, donc de 0€, les capitaux propres sont des fonds investis qui représentent un montant que les investisseurs mettent dans le but d'aider l'entreprise mais surtout avec l'objectif de se rembourser et dégager une plus value via les dividendes.
#
# > Dans le cas où ils ont dépensé la moitié les deux premières années et qu'il n'y a toujours aucun résultat, elle s'est appauvrie de 250M€.
#
# > Néanmoins dans le dernier cas avec le reste des fonds soit 250M€ restants l'entreprise acquiert une entreprise 25% plus chère par rapport à sa valeur :
#
# $$\text{Prix}= \text{Valeur} \times (1+25\%)$$
# $$\text{Valeur}=\frac{\text{Prix}}{(1+25\%)}$$
#
# Soit, la valeur de l'entreprise est :
# $$\text{Valeur}=\frac{250000000}{1,25}=200000000$$
#
# On obtient l'appauvrissement immédiat de cet achat en faisant la différence entre le montant payé et sa valeur :
# $$250M-200M=50M$$
# Comme l'entreprise améliore son résultat cette année de 75M€ grâce à des synergies, alors on détermine si elle s'enrichie ou s'appauvrie en faisant la différence entre l'enrichissement et l'appauvrissement : $75M-50M=25M$
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>À quels agrégats comptables correspond l'enrichissement théorique de chacun des acteurs suivants : les actionnaires, les créanciers, l'État ?</b>
#     </summary>
#
# 1. **Les actionnaires** : le résultat net lorsque les actionnaires décident de se rémunérer par dividendes.
# 2. **Les créanciers** : Frais financiers (intérêts)
# 3. **L'État** : Les impôts sur les sociétés.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Concrètement, en reprenant le schéma du paragraphe 3.15, de quoi l'entreprise s'enrichit-elle au cours d'un exercice donné ? Pourquoi</b>
#     </summary>
#
# > Le Schéma du paragraphe 3.15 résume les approches de présentation du compte de résultat (par nature | par fonction).
#
# Concrètement l'entreprise s'enrichit lorsqu'elle obtient un résultat net positif. Soit lorsque :
# $$\text{Résultat d'exploitation} - \text{Charges financières nettes des produits financiers} + \text{Résultat non récurrent} - \text{Impôt sur les sociétés} \geq 0$$
#
# </details>
#
# <details>
#     <summary>
#         <b>Commentez les deux phrases suivantes : "Cette année, nous allons devoir nous endetter pour combler nos pertes"; "le résultat que nous avons dégagé cette année va nous permettre de recheter notre principal concurrent".</b>
#     </summary>
#
# 1. Cette phrase confond l'objectif de l'endettement, il n'augmente pas la valeur de l'entreprise et doit être remboursé, si cet endettement à pour objectif de combler des pertes et non à proposer des solutions dans le but d'augmenter les resultats net de l'entreprise l'objectif n'est pas le bon. Néanmoins dans le sens de trésorerie, les pertes peuvent demander des besoins de trésorerie que l'endettement comble.
# 2. Le résultat dégagé pour l'entreprise ne constitue pas le moyen de financement d'un investissement, le résultat est une notion comptable virtuelle, c'est un indicateur d'enrichissement sur l'année, mais il peut y avoir un décalage de paiement, soit avoir un résultat de 100M€ mais ne rien avoir en banque. Il prend en compte aussi des charges non décaissées pour le moment, on achète pas une entreprise avec un résultat mais avec du cash. Il faut donc regarder au niveau de la trésorerie pour regarder les moyens de financement. Cela peut être le cas cependant lorsqu'il n'y a aucun décalage et que les flux de trésorerie net du même montant donc il n'y a pas de délais que ce soit pour les fournisseurs ou les clients, ce qui est très rare.
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Une année, une entreprise a généré un flux de trésorerie disponible négatif. A-t-elle détruit ou créé de la richesse ?</b>
#     </summary>
#
# On obtient un flux de trésorerie disponible négatif lorsque :
# $$\text{Flux de Trésorerie Disponible} = \text{recettes perçues} - \text{dépenses de consommation courantes} - \text{dépenses d'investissement} \leq 0$$
#
# Cela veut dire qu'on à les dépenses d'investissements et de consommations courantes qui sont supérieures aux recettes percues.
#
# On a soit investissement exceptionnel soit des matières premières et stock supérieurs à ceux habituels :
#
# Ce flux de trésorerie négatif crée de la richesses dans le cas où ces flux négatifs correspondent à la création de produit final qui a une valeur supérieure aux charges utilisées lors de la production.
# Cependant dans le cas où ces flux négatifs correspondent à une mauvaise production et des charges surdimensionées pour un produit final qui ne vaut pas plus que les charges utilisées alors il y a une destruction de richesse.
#
# Dans les deux cas il y aura une destuction de richesse et une création de richesse car pour créer de la richesse il faut en détruire donc réellement on ne peut pas directement répondre à la question si elle a créé ou détruit de la richesse.
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Un Excédent Brut d'exploitation apparaît-il nécessairement en trésorerie lorsqu'il est constraté comptablement ?</b>
#     </summary>
#
# >Non, l'EBE prend en compte les échanges futurs, livraisons/facturations qui correspondent au cycle d'exploitation actuel, mais cela ne veut pas dire que que des flux liés à cette exploitation ont déja eu lieu, par exemple les dépenses d'exploitations au fournisseur se font peut être à la fin de l'exploitation et ne sont pas encore présents dans les flux de trésorerie. Idem pour les paiements des clients qui ne sont peut être pas encore présents dans les flux mais comptabilisés car une facturation à la date actuelle est effectuée.
#
# En comptabilité l'EBE est calculé selon la comtabilité d'engagment, dès que la prestation est faite ou le produit livré on enregistre la vente, même si le client à 60 jours pour payer.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Peut-on dire que l'entreprise s'enrichit chaque année de son excédent brut d'exploitation ?</b>
#     </summary>
#
# 1. De plus l'EBE ne prend pas en compte les impôts, les charges financières, sans oublier la dotation aux amortissements qui correspond à la dépreciation d'un actif du à son utilisation courante par l'entreprise.
# 2. Pour cela il faut donc regarder le Résultat Net
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Suivant la terminologie adoptée au chapitre 2, la dotation aux amortissements constitue-t-elle une dépense ou une charge ? Précisez les différences existant entre ces deux concepts.</b>
#     </summary>
#
# La dotation aux amortissements est la perte de valeur d'un actif lié à son utilisation par l'entreprise.
#
# >Dépense : Décaissement réel de trésorerie.
#
# >Charge : Appauvrissement comptable sans mouvement de flux de trésorerie nécessaire.
#
# La dépense pour cet actif à lieu lors de l'achat de celui-ci. La dotation aux amortissement constitue un appauvrissement comptable, ce qui correspond à la notion de charge.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Analysez les points communs et les diférences entre l'optique de trésorerie et l'optique patrimoniale, en prenant pour exemple l'achat d'un terrain et l'investissement dans la recherche.</b>
#     </summary>
#
# 1. **Points Communs :**
# Dans les deux cas achat de terrain ou recherche, l'impact initial est identique pour la trésorerie : il y a une sortie de cash, qu'on achète un terrain ou qu'on paie des chercheurs, l'argent quitte le compte en banque. A l'instant T le flux de trésorerie est négatif.
#
# Finalité : Les deux opérations sont des paris sur l'avenir. On débourse aujourd'hui dans l'espoir que cela serve l'activité plus tard.
#
#
# 2. **Différences**
#
# L'achat d'un terrain :
#     -Optique trésorerie : L'entreprise à dépensé 100 000€
#     -Optique Patrimoniale : L'entreprise ne s'est pas appauvrie. Elle a simplement transformé un actif (cash) en un autre (terrain). Sa richesse totale reste inchangée.
#
# Le terrain étant un actif non amortissable. Sauf catastrophe, sa valeur restera inscrite au bilan pour toujours au prix d'achat.
#
# L'investissement dans la recherche :
#     -Optique trésorerie : Sortie de cash (salaires, matériel ...) et on espère que la dépense va créer un actif immatériel (brevet, savoir faire)
#     -Optique patrimoniale : La recherche est considérée comme une charge, on considère que l'entreprise s'appauvrit immédiatement car on ne sait pas si la recherche va aboutir.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Le remboursement d'un emprunt apparaît-il nécessairement au compte de résultat ? En trésorerie ?</b>
#     </summary>
#
# Non sur le compte de résultat le remboursement du capital n'apparaît pas au compte de résultat, parce que rembourser un prêt n'est pas une charge qui m'appauvrit. Quand j'ai reçu les 100 000 au début par exemple, ce n'était pas un produit, c'était une dette. quand je les rends, ce n'est pas une perte c'est juste l'annulation de cette dette, je rends ce qu'on m'a prêté.
#
# Par contre les Intêrets eux apparaissent toujours au compte de résultat, car c'est le prix du service par la banque. Ils sont classés dans les **Charges Financières**. Contrairement au capital, les intérêts représent un véritable appauvrissement.
#
# En ce qui concerne les flux de trésorerie peu importe que ce soit l'intérêt ou le capital, si l'argent sort de la banque il apparaît dans mes flux de trésorerie.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>L'augmentation de la valeur nominale d'un bien liée à l'inflation apparaît-elle au compte de résultat ?</b>
#     </summary>
#
# Non par convention comptable, sauf cas de très forte inflation. Le compte de résultat est une liste de ce que l'entreprise a gagné (**Produit**) et consommé (**Charges**) durant l'année.
#
# Une augmentation de valeur due à l'inflation est ce qu'on appelle un **gain latent**. Pour la comptabilité un gain n'est un produit que s'il est réalisé. Tant que l'entreprise n'a pas vendu le bien, il n'y a aucun chiffre d'affaires généré ou de produit exceptionnel. L'entreprise possède juste quelque chose qui vaut plus cher sur le marché mais cela ne rempli pas les caisses en temps normal.
#
# **Principe de Prudence** :
# Si un bien perd de la valeur, on enregistre une Dotation (une charge) pour montrer qu'on s'est appauvrit.
#
# Si un bien gagne de la valeur (via l'inflation par exemple), on n'enregistre rien du tout, on attend que l'argent soit matérialisé par une vente pour l'inscrire en tant que profit.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Pourquoi l'augmentation des stocks de matière première vient-elle en diminution des achats dans le compte de résultat ?</b>
#     </summary>
#
# Parce que l'augmentation des stocks correspond à des achats stockés, puisqu'ils n'ont pas servi à la production de l'exercice, ils doivent être neutralisés pour que le compte de résultat ne reflète que la consommation. La charge de l'année ne sera représentée que par les matières premières consommées soit :
#
# $$\text{Charge de l'année (matière première)} = \text{Achat matières premières} + \text{stock initial de matières premières} - \text{stock final de matière premières} $$
#
# $$ \text{Augmentation des stocks de matières première} = \text{stock final de matières premières} - \text{stock initial de matières premières}>0 $$
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Pourquoi la variation des stocks de produits finis figure-t-elle en produits dans le compte de résultat par nature ?</b>
#     </summary>
#
# Par nature le produit fini a une valeur, donc savoir qu'à la fin de l'exercice il reste x produits fini permet de jauger la valeur de produit en stock.
#
# Cela indique que des matières premières ont été consommées mais que des produits sont non vendus. L'entreprise veut savoir ce qu'elle a produit :
#
# $$ \text{Production de l'exercice} = \text{Ventes(Production vendue)} + \text{Variation de stock (Production stockée) }$$
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>La cession d'un actif immobilisé fait-elle partie de l'activité normale d'une entreprise ? Qu'enregistrera-t-on au compte de résultat ? Pourquoi ? </b>
#     </summary>
#
# >La cession d'un actif immobilisé ne fait partie de l'activité normale d'une entreprise, si l'actif est catégorisé comme immobilisé c'est par ce qu'il compte comme actif qui perd de la valeur au fil des années par rapport à sa production soit il se dissocie d'une charge qui elle fait référence aux actifs consommés lors d'un seul cycle.
#
# Lorsqu'il y a cession de celui-ci alors on l'enregistre au compte de résultat par rapport au montant de la plus ou moins value en tant que produit exceptionnel ou non récurrent, car ce type de vente ne doit pas fausser l'analyse de la performance opérationnelle de l'entreprise.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Illustrez sur plusieurs exemples la distinction entre produits et recettes, dépenses et charges.</b>
#     </summary>
#
# **Produit et recettes** : La différence se fait avec Produit qui fait référence à la comptabilité et recettes aux flux de trésorerie. On a lors de la livraison pour une entreprise qui livre des CPU, les recettes sont le cash reçu par l'entreprise lors de la vente des puces et celle-ci peut avoir un délai par rapport à la date de livraison donc ce flux sera visible dans x jours par rapport à la livraison, alors que les produits sont la valeur des produits finis vendus(Chiffre d'affaires) durant ce même exercice.
#
# **Dépenses et Charges** : La différence se fait de la même façon entre ce qui est caractérisé par un flux sortant de l'entreprise en cash (dépense) qui part au fournisseur (avec ou sans délai de paiement) pour acquérir un bien nécessaire à l'entreprise alors que les charges sont les éléments consommés lors de l'exercice. On peut par exemple dépenser 1K euros pour les matières premières nécessaires à la fabrication des puces (silicium) et pourtant n'utiliser dans l'exercice lors de la production l'équivalent de 700€, il en reste donc en stock et les charges font référence à ce qui a été consommé dans l'exercice.
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Le compte de résultat diffère-t-il beaucoup du budget de trésorerie ?</b>
#     </summary>
#
# Oui car il faut prendre en compte les décalages de paiements que ce soit du client ou du fournisseur, cela crée des différences entre les deux sans oublier les notions de stock et variation de stock au niveau des charges et produits finis. La notion d'investissement et financement aussi :
#
# - L'investissement : si j'achète une machine à 100K€, le budget de trésorerie enregistre une sortie de 100K€, le compte de résultat lui ne verra qu'une petite fraction de l'amortissement.
# - L'emprunt : Recevoir un prêt de 100K€ augmente ma trésorerie, mais n'est pas un produit dans le compte de résultat, ce n'est pas un gain mais une dette.
#
#
# </details>
#
# ---
#
# <details>
#     <summary>
#         <b>Qu'est ce qu'une charge calculée ? et une charge constatée d'avance ?</b>
#     </summary>
#
# Une **charge calculée** est une charge qui ne correspond pas à une facture ou à une sortie d'argent immédiate. On l'appelle "calculée" car son montant est déterminé par un calcul interne à l'entreprise.
#
# On en distingue deux types principaux :
#     **Les Dotations aux Amortissements** : C'est la charge calculée la plus courante. On calcule l'usure d'une machine (ex: Prix/10 ans). L'argent ne sort pas de la banque, mais on inscrit cette charge pour montrer que l'outil de travail perd de la valeur.
#
# **Les Dotations aux Provisions** : Si tu penses qu'un client ne va pas te payer ou que tu vas perdre un procès, tu calcules le risque et tu l'inscris en charge. Là encore, c'est un calcul d'anticipation, pas une facture reçue.
#
# Une **charge constatée d'avance** est une charge qui a déja été facturée et enregistrée, mais qui concerne ou en partie l'exercice suivant :
# On veut dans le compte de résultat que les charges qui concernent l'année en cours.
#
# </details>
